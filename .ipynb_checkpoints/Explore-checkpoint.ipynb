# %%
Explore.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Explore.ipynb
#
# NameError: name 'Explore' is not defined
